# %%
#### for running in google colab
# !wget https://github.com/PedramMouseli/MSK_pain_prediction/archive/refs/heads/main.zip
# !unzip /content/master.zip

# %%
import os
from pathlib import Path
os.chdir(Path().cwd().parent)

# %%
# install requirements - Google colab
# !pip install -r requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob
from os.path import basename
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.stats import ttest_ind, pearsonr
from mlxtend.evaluate import permutation_test
from sklearn.linear_model import LinearRegression
import seaborn as sns
from src.utils import nirs_features, entropy, extraxt_wt_power, SeabornFig2Grid, load_ratings, plot_predictions, plot_feature_selection
from src.models import regression_fit_cv, regression_fit
import pickle

# %% [markdown]
# ## Import data

# %%
# import participants data
participants_df = pd.read_csv("./data/participants.csv")
ratings_path = "./data/StO2AssessmentForm_DATA.csv"

# path to NIRS and EMG data
trials_path_nirs = "./data/nirs"
trials_path_emg = "./data/emg"

# %%
import os
import glob
for sub in sorted(glob.glob(f'{trials_path_emg}/*')):
    sub_id = os.path.basename(sub)
    if sub_id[:7] not in participants_df['sub_num'].tolist():
        print(sub_id[:7])
#         os.remove(sub)

# %%
sub_list = []

exclusion_list = []

sub_sex = []
age = []

pkl_list_nirs = []
pkl_list_emg = []

for j, sub_id in enumerate(participants_df['sub_id']):
    sub_params = participants_df.loc[participants_df['sub_id']==sub_id]
    
    sub_num = sub_params['sub_num'].item()
    
    # ignore excluded subjects
    if sub_id in exclusion_list:
        continue
    sub_list.append(sub_num)
    
    # import NIRS trials
    nirs_df = pd.read_pickle(f'{trials_path_nirs}/{sub_num}_nirs.pkl')
    pkl_list_nirs.append(nirs_df)
    
    # import EMG trials
    emg_df = pd.read_pickle(f'{trials_path_emg}/{sub_num}_emg.pkl')
    pkl_list_emg.append(emg_df)

    sub_sex.append((sub_params['sex']).item())
    age.append(float(sub_params['age']))

    
nirs_clench = pd.concat(pkl_list_nirs, keys = sub_list)
emg_clench = pd.concat(pkl_list_emg, keys = sub_list)

sub_sex = np.array(sub_sex)
age = np.array(age)

sub_sex[sub_sex=='Female'] = 0
sub_sex[sub_sex=='Male'] = 1
sub_sex = np.array(sub_sex).astype(int)

print('Data imported successfully!')
# Out:
# Data imported successfully!

# %% [markdown]
# ## Extract NIRS features

# %%
##### extract NIRS features
diff_coef, task_median, pre_rest_median = nirs_features(sub_list,
                                                           nirs_clench,  
                                                           measure='tsi', side='r', sensor='1')
print('NIRS features extracted!')
# Out:
# NIRS features extracted!

# %% [markdown]
# ## Extract EMG features

# %%
##### extract EMG entropy features
# this takes time. We can load the saved values by running the next cell

# task_ent, ent_coef_task = entropy(sub_list, emg_clench, side='r')

# %%
# load sample entropy values
with open('./data/sample_entropy.pickle', 'rb') as handle:
    sample_entropy = pickle.load(handle)

# %%
##### extract wavelet transformed EMG power
wt_coef_task = extraxt_wt_power(sub_list, emg_clench, side='r')

# %%
##### import ratings
pain_df, fatigue_df = load_ratings(participants_df, ratings_path)

# %%
pain_rm = np.zeros(len(sub_list))
pain_rm_mat = np.zeros([len(sub_list), 16])
for j,sub in enumerate(sub_list):
    pain_rm[j] = float(pain_df.loc[(pain_df['subject']==sub) &  (pain_df['trial']==16) &  (pain_df['muscle']=='right masseter')]['pain'])
    pain_rm_mat[j] = np.array(pain_df.loc[(pain_df['subject']==sub) &  (pain_df['muscle']=='right masseter')]['pain'])
    
pain_diff = pain_rm_mat[:,15] - pain_rm_mat[:,0]

# %% [markdown]
# ## Training models

# %% [markdown]
# Training the model based on NIRS features:

# %%
feature_labels = ['sign(NIRS slope)', 'abs(NIRS slope)', 'normalized median 1-3', 
                  'normalized median 4-6', 'normalized median 7-9', 'normalized median 10-12', 
                  'normalized median 13-15']
target_df_nirs, scores, coefs_nirs, feature_imp, corr, p_val, support = regression_fit_cv(np.c_[np.sign(diff_coef), np.abs(diff_coef), np.mean(task_median.reshape(-1, 3), axis=1).reshape(-1,5) - np.expand_dims(pre_rest_median, axis=1)],
                                                                                         np.c_[pain_rm, sub_sex], model='PLSc',
                                                                                         plot_path=None, feature_labels=feature_labels, num_iter=1, max_iter=1000000, plot_pred=False,
                                                                                         plot_weight=False, save_plot=False, feature_selection=True, selection_method='single', 
                                                                                         inner_k=10, outer_k=10, verbos=True, feature_type='NIRS', target='pain_rm')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# processing fold: 1
# # selected features:  3
# fold 1 took 0.317 seconds
#
# processing fold: 2
# # selected features:  2
# fold 2 took 0.263 seconds
#
# processing fold: 3
# # selected features:  2
# fold 3 took 0.266 seconds
#
# processing fold: 4
# # selected features:  3
# fold 4 took 0.311 seconds
#
# processing fold: 5
# # selected features:  3
# fold 5 took 0.307 seconds
#
# processing fold: 6
# # selected features:  2
# fold 6 took 0.261 seconds
#
# processing fold: 7
# # selected features:  1
# fold 7 took 0.215 seconds
#
# processing fold: 8
# # selected features:  3
# fold 8 took 0.32 seconds
#
# processing fold: 9
# # selected features:  1
# fold 9 took 0.21 seconds
#
# processing fold: 10
# # selected features:  2
# fold 10 took 0.266 seconds

# %%
modality = 'NIRS'
target = 'MVC pain'
plot_predictions(coefs_nirs, target_df_nirs, modality, target, plot_path=None, save_plot=False)
# Out:
# modality:  NIRS

# %% [markdown]
# Training the model based on EMG features:

# %%
target_df_emg, scores, coefs_emg, feature_imp, corr, p_val, support = regression_fit_cv(np.c_[np.sign(sample_entropy['ent_coef_task']), np.abs(sample_entropy['task_ent'][:,14]-sample_entropy['task_ent'][:,0]), np.sign(wt_coef_task)], np.c_[pain_rm, sub_sex], model='PLSc',
                                                                   plot_path=None, feature_labels=feature_labels, num_iter=1, max_iter=1000000, plot_pred=False,
                                                                   plot_weight=False, save_plot=False, feature_selection=True, selection_method='single', 
                                                                   inner_k=10, outer_k=10, verbos=True, feature_type='EMG', target='pain_rm')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# processing fold: 1
# # selected features:  4
# fold 1 took 0.565 seconds
#
# processing fold: 2
# # selected features:  3
# fold 2 took 0.48 seconds
#
# processing fold: 3
# # selected features:  3
# fold 3 took 0.482 seconds
#
# processing fold: 4
# # selected features:  3
# fold 4 took 0.484 seconds
#
# processing fold: 5
# # selected features:  3
# fold 5 took 0.476 seconds
#
# processing fold: 6
# # selected features:  4
# fold 6 took 0.548 seconds
#
# processing fold: 7
# # selected features:  2
# fold 7 took 0.399 seconds
#
# processing fold: 8
# # selected features:  3
# fold 8 took 0.479 seconds
#
# processing fold: 9
# # selected features:  4
# fold 9 took 0.547 seconds
#
# processing fold: 10
# # selected features:  4
# fold 10 took 0.562 seconds

# %%
modality = 'EMG'
target = 'MVC pain'
plot_predictions(coefs_emg, target_df_emg, modality, target, plot_path=None, save_plot=False)
# Out:
# modality:  EMG

# %% [markdown]
# Training the model based on NIRS and EMG features:

# %%
target_df, scores, coefs, feature_imp, corr, p_val, support = regression_fit_cv(np.c_[np.sign(diff_coef), np.abs(diff_coef), np.mean(task_median.reshape(-1, 3),
                                                                                axis=1).reshape(-1,5) - np.expand_dims(pre_rest_median, axis=1),
                                                                                np.sign(sample_entropy['ent_coef_task']), np.abs(sample_entropy['task_ent'][:,14]-sample_entropy['task_ent'][:,0]), np.sign(wt_coef_task)],
                                                                                np.c_[pain_rm, sub_sex], model='PLSc',
                                                                                plot_path=None, feature_labels=feature_labels, num_iter=1, max_iter=1000000, plot_pred=False,
                                                                                plot_weight=False, save_plot=False, feature_selection=True, selection_method='single',
                                                                                inner_k=10, outer_k=10, verbos=True, feature_type='NIRS_EMG', target='pain_rm')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# processing fold: 1
# # selected features:  6
# fold 1 took 1.208 seconds
#
# processing fold: 2
# # selected features:  5
# fold 2 took 1.043 seconds
#
# processing fold: 3
# # selected features:  8
# fold 3 took 1.406 seconds
#
# processing fold: 4
# # selected features:  7
# fold 4 took 1.284 seconds
#
# processing fold: 5
# # selected features:  5
# fold 5 took 1.049 seconds
#
# processing fold: 6
# # selected features:  6
# fold 6 took 1.184 seconds
#
# processing fold: 7
# # selected features:  5
# fold 7 took 1.072 seconds
#
# processing fold: 8
# # selected features:  6
# fold 8 took 1.206 seconds
#
# processing fold: 9
# # selected features:  6
# fold 9 took 1.197 seconds
#
# processing fold: 10
# # selected features:  8
# fold 10 took 1.404 seconds

# %%
modality = 'NIRS_EMG'
target = 'MVC pain'
plot_predictions(coefs, target_df, modality, target, plot_path=None, save_plot=False)
# Out:
# modality:  NIRS_EMG

# %% [markdown]
# ## Selected features

# %% [markdown]
# Training 1000 models (100 iteration, 10 fold cross-validation) and counting how many times each feature is selected by the algorithm:

# %%
target_df_fs, scores, coefs_fs, feature_imp, corr, p_val, support = regression_fit_cv(np.c_[np.sign(diff_coef), np.abs(diff_coef), np.mean(task_median.reshape(-1, 3),
                                                                                axis=1).reshape(-1,5) - np.expand_dims(pre_rest_median, axis=1),
                                                                                np.sign(sample_entropy['ent_coef_task']), np.abs(sample_entropy['task_ent'][:,14]-sample_entropy['task_ent'][:,0]), np.sign(wt_coef_task)],
                                                                                np.c_[pain_rm, sub_sex], model='PLSc',
                                                                                plot_path=None, feature_labels=feature_labels, num_iter=100, max_iter=1000000, plot_pred=False,
                                                                                plot_weight=False, save_plot=False, feature_selection=True, selection_method='single',
                                                                                inner_k=10, outer_k=10, verbos=False, feature_type='NIRS_EMG', target='pain_rm')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
modality = 'NIRS_EMG'
plot_feature_selection(support, modality, plot_path=None, save_plot=False)

# %% [markdown]
# ## Training the final model

# %% [markdown]
# Training the model on the whole training data using the selected features.
# This model will be tested on the validation data.

# %%
target_df_final, coefs_final, model = regression_fit(np.c_[np.sign(diff_coef), 
                                                           np.mean(task_median.reshape(-1, 3), axis=1).reshape(-1,5)[:,1] - pre_rest_median,
                                                           np.sign(sample_entropy['ent_coef_task']), np.abs(sample_entropy['task_ent'][:,14]-sample_entropy['task_ent'][:,0]), 
                                                           np.sign(wt_coef_task)[:,8]], 
                                                           y=pain_rm, 
                                                           sex=sub_sex,
                                                           max_iter=1000000)

# %%
modality = 'NIRS_EMG_final'
target = 'MVC pain'
plot_predictions(coefs_final, target_df_final, modality, target, plot_path=None, save_plot=False)
# Out:
# modality:  NIRS_EMG_final
